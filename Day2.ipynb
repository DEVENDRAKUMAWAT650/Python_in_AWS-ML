# %% [markdown]
# <a href="https://colab.research.google.com/github/DEVENDRAKUMAWAT650/Python_in_AWS-ML/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#string
room = 'vishal'
print(room)
print(id(room))
room='vishal2'
print(room)
print(id(room))
# Out:
# vishal
# 140481938978784
# vishal2
# 140481938972016

# %%
#int
room = 10000
print(room)
print(id(room))
room = 200000
print(room)
print(id(room))
# Out:
# 10000
# 140481938993520
# 200000
# 140481938995408

# %%
#flaot
room = 1000.20
print(room)
print(id(room))
room=10000.20
print(room)
print(id(room))
# Out:
# 1000.2
# 140481938993328
# 10000.2
# 140481938996848

# %%
#bool
room = True
print(room)
print(id(room))
room = False
print(room)
print(id(room))
# Out:
# True
# 10549600
# False
# 10549568
