# %% [markdown]
# <a href="https://colab.research.google.com/github/DEVENDRAKUMAWAT650/Python_in_AWS-ML/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
  name = 'nikhil'
  roll_no = 101
s=Student()# s is object
print(s.name)# name is attribute
print(s.roll_no)
# Out:
# nikhil
# 101

# %%
class Student:
  def __init__(self,name,roll_no):#constructor | self -> this  #self use the this keyword type
    self.name=name
    self.roll_no=roll_no
s=Student("nikhl",123)
print(s.name)
print(s.roll_no)
# Out:
# nikhl
# 123

# %%
class Student:
  def __init__(self,name,roll_no,age):
    self.name=name
    self.roll_no=roll_no
    self.age=age
s=Student('nikhil',123,20)
print(s.name)
print(s.roll_no)
print(s.age)
# Out:
# nikhil
# 123
# 20

# %%
class Student:
  def __init__(self,name,roll_no,age,course,fees,city,state,country):  #self ---> use this
    self.name=name
    self.roll_no=roll_no
    self.age=age
    self.course=course
    self.fees=fees
    self.city=city
    self.state=state
    self.country=country
s=Student('nikhil',123,20,'python',10000,'jaipur','Rajasthan','india')
print(s.name,s.roll_no,s.age,s.course,s.fees,s.city,s.state,s.country)
# Out:
# nikhil 123 20 python 10000 jaipur Rajasthan india

# %%
class Student:
  def __init__(self,name,roll_no,age=None):
    self.name=name
    self.roll_no=roll_no
    self.age=age
s=Student('nikhil',123)
print(s.name,s.roll_no,s.age)
s1=Student('raj',123,20)
print(s1.name,s1.roll_no,s1.age)
# Out:
# nikhil 123 None
# raj 123 20

# %%
class Student:
  def __init__(this,*args):
    print(type(args))
    print(args)
s=Student('nikhil',123)
# Out:
# <class 'tuple'>
# ('nikhil', 123)

# %%
class Student:
  def __init__(self,*args):
    self.data=args
s=Student('nikhil',123,20)
print(s.data[0],s.data[1],s.data[2])
# Out:
# nikhil 123 20

# %%
class Student:
  def __init__(self,*args):
    self.data=args
s=Student(['nikhil',123,20])
print(s.data[0][0])
# Out:
# nikhil

# %%
#Example
class Student:
  def __init__(self,*args):
    self.data=args
s=Student({'users':['nikhil','raj','Abhishek','vineet']},{'address':{"home-town":"kukas","office":"jaipur"}})
print() # all users , kukas ,jaipur
for i in s.data[0]['users']:
  print(i)
print(s.data[1]['address']['home-town'])
print(s.data[1]['address']['office'])
# Out:
# nikhil
# raj
# Abhishek
# vineet
# kukas
# jaipur

# %%
#Example
class Student:
  def __init__(self,*args):
    self.data=args
s=Student({'users':['nikhil','raj','Abhishek','vineet']},{'address':{"home-town":"kukas","office":"jaipur"}})
print() # all users , kukas ,jaipur
for i in s.data[0]['users']:
  print(i)
for i in s.data[1]['address'].keys():
  #print(i)
 print(s.data[1]["address"][i])
# Out:
# nikhil
# raj
# Abhishek
# vineet
# kukas
# jaipur

# %%
class Student:
  def __init__(self,*args):
    self.data=args
s=Student({'users':['nikhil','raj','Abhishek','vineet']},{'address':{"home-town":"kukas","office":"jaipur"}})
print() # all users , kukas ,jaipur
for i in s.data[0]['users']:
  print(i)
for i in s.data[1]['address']['home-town']:
  print(i)
for i in s.data[1]['address']['office']:
    print(i)
# Out:
# nikhil
# raj
# Abhishek
# vineet
# k
# u
# k
# a
# s
# j
# a
# i
# p
# u
# r

# %%
class Student:
  def __init__(self,name,roll_no,age):
    self.name=name
    self.roll_no=roll_no
    self.age=age
  #get
  def getName(self):
    print(self.name)
  #update
  def updateName(self):
   self.name = 'hello'
   print(self.name)
  #delete
  def deleteName(self):
    del self.name
    #print(self.name)
  #create
  def createName(self):
    self.name='Nikhil Saini'
    print(self.name)
s=Student('nikhil',123,20)
s.getName()
s.updateName()
s.deleteName()
s.createName()
# Out:
# nikhil
# hello
# Nikhil Saini

# %%
class Student:
  def __init__(self,name,roll_no):
    print("auto start")
    self.name = name
    self.roll_no = roll_no
  # get
  def updateName(self,name=None): # default value -> none
    if name != None:
      self.name = name
    print(self.name)


inst = Student("nikhil",123)
inst.updateName("rajendra")

inst1 = Student("abhishek",321)
inst1.updateName()
# Out:
# auto start
# rajendra
# auto start
# abhishek

# %% [markdown]
# # #**Inheritance**

# %%
class Student:
  def __init__(self,name,roll_no):
    self.name=name
    self.roll_no=roll_no
  def getData(self):
    print(self.name,self.roll_no)

class Address:
  def __init__(self,city,state):
    self.city=city
    self.state=state
  def getData(self):
    print(self.city,self.state)


s=Student('nikhil',123)
s.getData()
a=Address('jaipur','Rajasthan')
a.getData()
# Out:
# nikhil 123
# jaipur Rajasthan

# %%
class Student:
  def __init__(self,name,roll_no):
    self.name=name
    self.roll_no=roll_no
  def getData(self):
    print(self.name,self.roll_no)

class Address(Student):
  def __init__(self,name,roll_no,city,state):
    self.city=city
    self.state=state
    super().__init__(name,roll_no)
    #extra(repeat)
    #self.name=name
    #self.roll_no=roll_no
  def getAddress(self):
    print(self.city,self.state)
a=Address('nikhil',123,'jaipur','Rajasthan')
a.getData()
a.getAddress()
# Out:
# nikhil 123
# jaipur Rajasthan
